# %% [markdown]
# ## Numerical Investigation of Quantum Tunneling in a Quartic Double-Well Potential using the **Eigenstate Expansion**.
#
# - Objective
#   - Develop a general numerical solver for the one-dimensional Time-Independent Schrödinger Equation (TISE), validate it using the quantum harmonic oscillator, apply it to a quartic double-well potential, and use the computed eigenstates to study the time evolution of a Gaussian wave packet and the resulting quantum tunneling.

# %% [markdown]
# I will work upon two different potential
# 1. Harmonic Oscillator(Validation)$$V(x)=\frac{1}{2}m\omega^2x^2$$
#   - Why? $\rightarrow$ Verify that the numerical solver is correct because the exact solution is know.
# 1. Quartic DOuble Well $$V(x) = -\frac{1}{2}\alpha x^2 + \beta x^4$$
#   - Why? $\rightarrow$ To study quantum tunneling numerically.
#
#
# **My major tasks will be**:-
# 1. Validate the Numerical Solver for *Harmonic Oscillator*
#   - Find
#     1. First 20 eigenvalues and 20 eigenfunctions
#     2. Error Table
#     3. Eigenvalue comparission plot
#     4. Eigenfunction plots
# 2. Quartic Double-Well Eigenstates
#   - Find
#     1. First 20 eigenvalues and 20 eigenstates
#     2. Grid Convergenece
#     3. Potential with eigenfunctions
#     4. Energy Spectrum
# 3. Gaussian Wave Packet Expansion
#   - Find
#     1. Gaussian wave packet
#       1. find minimum of double well
#       2. Construct initial Gaussian wave packet localized near the left minima
#       3. Expand Gaussian
#     2. Expansion coefficient $c_n$
#     3. Plot of |c_n|^2
#     4. Time Evolution of $\Psi(x,t)$
#     5. Plot/animation of $|\Psi(x,t)|^2$
#     6. Analysis of tunneling

# %% [markdown]
# Choose Potential
#         │
#         ▼
# Discretize Space
#         │
#         ▼
# Construct Hamiltonian
#         │
#         ▼
# Diagonalize Hamiltonian
#         │
#         ▼
# Obtain First 20 Eigenvalues & Eigenfunctions
#         │
#         ├─────────────────────┐
#         │                     │
#         ▼                     ▼
# Validate (HO)          Quartic Double Well
#                               │
#                               ▼
#                  Create Gaussian Wave Packet
#                               │
#                               ▼
#               Project onto Numerical Eigenbasis
#                               │
#                               ▼
#                 Compute Expansion Coefficients
#                               │
#                               ▼
#                   Check Basis Convergence
#                               │
#                               ▼
#                  Compute Time Evolution
#                               │
#                               ▼
#                         Plot |Ψ(x,t)|²
#                               │
#                               ▼
#                 Observe Quantum Tunneling

# %%
import numpy as np
